# %%
# !gdown --id 18nlV4YjPM93o-SdnPQrvauMN_v-oizmZ
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=18nlV4YjPM93o-SdnPQrvauMN_v-oizmZ
# To: /content/UCF_and_Shanghai.zip
# 617MB [00:05, 121MB/s]

# %%
# !unzip /content/UCF_and_Shanghai.zip -d /content/sample_data
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/sample_data/UCF-Crime/all_flows/Shooting/Shooting040_x264.mp4.npy
#   inflating: /content/sample_data/UCF-Crime/all_flows/Shooting/Shooting036_x264.mp4.npy
#   inflating: /content/sample_data/UCF-Crime/all_flows/Shooting/Shooting039_x264.mp4.npy
#   inflating: /content/sample_data/UCF-Crime/all_flows/Shooting/Shooting030_x264.mp4.npy
#   inflating: /content/sample_data/UCF-Crime/all_flows/Shooting/Shooting002_x264.mp4.npy
#   inflating: /content/sample_data/UCF-Crime/all_flows/Shooting/Shooting027_x264.mp4.npy
#   inflating: /content/sample_data/UCF-Crime/all_flows/Shooting/Shooting014_x264.mp4.npy
#   inflating: /content/sample_data/UCF-Crime/all_flows/Shooting/Shooting023_x264.mp4.npy
#   inflating: /content/sample_data/UCF-Crime/all_flows/Shooting/Shooting047_x264.mp4.npy
#   inflating: /content/sample_data/UCF-Crime/all_flows/Shooting/Shooting024_x264.mp4.npy
# ...

# %%
# !pwd
# Out:
# /content

# %%
# !ls
# Out:
# Real-world-Anomaly-Detection-in-Surveillance-Videos-pytorch
# sample_data
# UCF_and_Shanghai.zip

# %%
# %cd model_code_repo
# Out:
# /content/model_code_repo

# %%
# !ls
# Out:
# dataset.py  main.py	sam.gif		    test_normalv2.txt
# learner.py  README.md	sample.gif	    train_anomaly.txt
# loss.py     result.png	test_anomalyv2.txt  train_normal.txt

# %%
# !python dataset.py
# Out:
# 140

# %%
# !pip install -U torch torchvision

# %%
# !python3 training.py
# Out:
# Epoch: 0
# loss = {} 0.9627994519692881
# /usr/local/lib/python3.7/dist-packages/torch/_tensor.py:575: UserWarning: floor_divide is deprecated, and will be removed in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values.
# To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor'). (Triggered internally at  /pytorch/aten/src/ATen/native/BinaryOps.cpp:467.)
#   return torch.floor_divide(self, other)
# auc =  0.797560364010341
#
# Epoch: 1
# loss = {} 0.9005895146617183
# auc =  0.8022280179672062
#
# Epoch: 2
# loss = {} 0.854022928962001
# auc =  0.8054947722228811
#
# Epoch: 3
# loss = {} 0.8054728154782895
# auc =  0.8114477398227347
#
# Epoch: 4
# loss = {} 0.7623338721416615
# auc =  0.8035179755745744
#
# Epoch: 5
# loss = {} 0.7302338348494636
# auc =  0.8154458135166512
#
# Epoch: 6
# ...
